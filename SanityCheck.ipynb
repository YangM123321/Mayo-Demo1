# %%
import pandas as pd
feat = pd.read_parquet("data/processed/features.parquet")
print(feat.shape)
feat.head()
# Out:
# (54, 13)
#    patient_id  BP_DIA_count  BP_DIA_last  BP_DIA_max  BP_DIA_mean  BP_DIA_min  \
# 0    10000032          23.0         60.0        64.0    50.217391        37.0
# 1    10001217           4.0         82.0        98.0    93.500000        82.0
# 2    10001725           2.0         80.0        91.0    85.500000        80.0
# 3    10002428          32.0         83.0       100.0    66.625000        39.0
# 4    10002930          63.0         91.0       103.0    76.746032        45.0
#
#    BP_DIA_std  BP_SYS_count  BP_SYS_last  BP_SYS_max  BP_SYS_mean  BP_SYS_min  \
# 0    7.954167          23.0         98.0       107.0    86.086957        65.0
# 1    7.724420           4.0        130.0       146.0   140.250000       130.0
# 2    7.778175           2.0        120.0       137.0   128.500000       120.0
# 3   15.798632          32.0        145.0       172.0   123.000000        80.0
# 4   12.186677          63.0        148.0       190.0   132.444444        97.0
#
#    BP_SYS_std
# ...
